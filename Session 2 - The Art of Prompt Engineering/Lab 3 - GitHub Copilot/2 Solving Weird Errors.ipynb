# %% [markdown]
# # Solving Weird Errors
#
# For example, you run a cell of code it reacts with a ton of error info, shown below.
# Copy the entire error (the cell output) and paste into GitHub Copilot with the prompt: What is this and how do I fix it?

# %% [markdown]
# ```python
# {
# 	"name": "OSError",
# 	"message": "[E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.",
# 	"stack": "---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 10
#       7 print(\"NLTK Tokenization:\", tokens_nltk)
#       9 # Tokenizing using spacy
# ---> 10 nlp = spacy.load(\"en_core_web_sm\")
#      11 doc = nlp(sentence)
#      12 tokens_spacy = [token.text for token in doc]
#
# File c:\\Users\\skingaby\\AppData\\Local\\anaconda3\\envs\\myEnv\\Lib\\site-packages\\spacy\\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     \"\"\"Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     \"\"\"
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File c:\\Users\\skingaby\\AppData\\Local\\anaconda3\\envs\\myEnv\\Lib\\site-packages\\spacy\\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory."
# }
# ```

# %% [markdown]
# ## Here's another example

# %% [markdown]
# ```text
# TITLE: Microsoft SQL Server 2022 Setup
# ------------------------------
#
# The following error has occurred:
#
# The Microsoft .NET Framework 2.0 or 4.0 must be installed on your computer before you can install Microsoft SQL Server 2022 Setup Support Files. Please install the .NET Framework 2.0 or 4.0 and then install Microsoft SQL Server 2022 Setup Support Files.
#
# For help, click: https://go.microsoft.com/fwlink?LinkID=2209051&ProdName=Microsoft%20SQL%20Server&EvtSrc=setup.rll&EvtID=50000&ProdVer=16.0.1000.6&EvtType=0xDF039760%25401201%25401
#
# ------------------------------
# BUTTONS:
#
# OK
# ```
