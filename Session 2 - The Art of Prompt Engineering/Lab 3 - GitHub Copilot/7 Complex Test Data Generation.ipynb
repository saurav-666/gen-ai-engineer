# %% [markdown]
# # Complex Test Data Generation

# %% [markdown]
# ```text
# I have a set of tables with Customer (ID, Name, CreditRating, CreditLimit, TaxExempt), CustomerAddress (ID, CustomerID, Address1, Address2, City, StateCode, Zip, PostCode, CountryCode) -- Use Zip for US, PostCode for CA, States (StateCode, StateName, TaxRate) -- States includes US States and Canadian Provinces and Territories, Countries (CountryCode, Name, TaxRate) -- Countries include only US and CA at this time, Orders (ID, CustomerID, BillToAddressID, ShipToBillingAddress, ShipToAddressID, TaxRate, TaxAmount, ShippingCharge, OrderTotal), Products (ID, SKU, Name, UOM, MSRP) -- SKU is a 10 character alphanumeric, UOM could be EA, LB, or KG, OrderDetails (ID, ProductID, Quantity, DiscountRate, MSRP, DiscountedPricePerUnit, NetPrice)
# All the IDs are automatically numbered. All the tables need a CreatedDate, CreatedBy, LastUpdatedDate, and LastUpdatedBy.
#
# First, generate the DDL to define the tables in MS SQL, including the Primary Key and Foreign Key relationships with the necessary constraints. Make sure to use [] where needed.
# Second, generate the insert statements to fully populate the Countries and States tables with all the US states and all the CA provinces. Be sure to use the INSERT INTO ... VALUES (...), (...), (...) syntax.
# Third, create a Python function to insert fake data for 100 Customers and their Addresses, and to insert 100 Products. Keep in mind the identity columns, foreign keys, and data types.
# Fourth, create a Python function to insert 200 Orders with 2-5 Order Details each. Maintain referential integrity and data types. Use random data for the Quantity, DiscountRate, and MSRP. Make sure the OrderTotal is calculated correctly.
# ```
