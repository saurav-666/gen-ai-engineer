# %% [markdown]
# # Connecting to models

# %%
import sys
sys.path.insert(1, '../../')
import init_creds as creds
 
AZURE_OPENAI_API_KEY = creds.get_api_key()
AZURE_OPENAI_ENDPOINT = creds.get_endpoint()
# print(AZURE_OPENAI_API_KEY)
# print(AZURE_OPENAI_ENDPOINT)
 
if not AZURE_OPENAI_API_KEY:
    raise ValueError("No AZURE_OPENAI_API_KEY set for Azure OpenAI API")
if not AZURE_OPENAI_ENDPOINT:
    raise ValueError("No AZURE_OPENAI_ENDPOINT set for Azure OpenAI API")

# %%
import os

os.environ["AZURE_OPENAI_API_KEY"] = AZURE_OPENAI_API_KEY
os.environ["AZURE_OPENAI_ENDPOINT"] = AZURE_OPENAI_ENDPOINT
os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"] = "gpt-4o-mini"
os.environ["AZURE_OPENAI_API_VERSION"]="2024-07-01-preview"


from langchain_openai import AzureChatOpenAI

# Create the model

model = AzureChatOpenAI(
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Help user answer questions"),
    HumanMessage(content="Who was Neil Amstrong?"),
]

reply=model.invoke(messages)
print(reply.content)

# %% [markdown]
# This will not run without your Open AI Key

# %%
# This will not run without your Open AI Key

import os

os.environ["OPENAI_API_KEY"] = # YOUR OPENAI API KEY

from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4")

# %% [markdown]
# This will not run without having the bigscience model downloaded

# %%
# This will not run without having the bigscience model downloaded
 
from langchain.llms import HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
    model_id="bigscience/bloom-1b7",
    task="text-generation",
    model_kwargs={"temperature": 0.0, "max_length": 64},
)
#llm("What is electroencephalography?")
llm("The first man on the moon was ...")

# %% [markdown]
# This will not run without having the phi3 model downloaded

# %%
# This will not run without having the phi3 model downloaded

from langchain.chat_models.ollama import ChatOllama

model = ChatOllama(model="phi3")

from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Help user answer questions"),
    HumanMessage(content="Who was Neil Amstrong?"),
]

reply=model.invoke(messages)
print(reply.content)
