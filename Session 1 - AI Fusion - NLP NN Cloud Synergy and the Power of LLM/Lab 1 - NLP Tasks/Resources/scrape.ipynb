# %%
import requests
from bs4 import BeautifulSoup
import re
import time
from urllib.parse import urljoin
import logging

# log to a file
logging.basicConfig(filename='smart_stories.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
log = logging.getLogger(__name__)

def get_smart_stories():
    # get the page
    base_url = 'https://www.thesmartfactory.io/'
    url = urljoin(base_url, 'smart-stories.html')
    log.info(f'Getting page {url}')
    r = requests.get(url)
    log.info(f'Got page {url} with status code {r.status_code}')
    log.info(f'Page content: {r.text}')
    r.raise_for_status()
    log.info('Parsing the page')
    soup = BeautifulSoup(r.text, 'html.parser')
    log.info(f'Page Parsed: {soup.contents}')
    log.info('Finding all the links')
    links = soup.find_all('a', href=re.compile('^smart-stories'))
    log.info(f'Found {len(links)} links')
    # get the href and the text
    log.info('If the link text is "Learn more", get the linked page')
    links = [(link['href'], link.text) for link in links if link.text.startswith('Learn more')]
    log.info(f'Found {len(links)} links with text "Learn more"')
    # get the text from the linked page
    stories = []
    for link in links:
        full_url = urljoin(base_url, link[0])
        log.info(f'Getting page {full_url}')
        r = requests.get(full_url)
        log.info(f'Got page {full_url} with status code {r.status_code}')
        r.raise_for_status()
        soup = BeautifulSoup(r.text, 'html.parser')
        stories.append(soup.get_text())
        time.sleep(2)
    log.info(f'Collected {len(stories)} stories')
    return stories

if __name__ == '__main__':
    stories = get_smart_stories()
    # Save the stories to a txt file
    with open('smart_stories.txt', 'w', encoding='utf-8') as f:
        for story in stories:
            f.write(story)
            f.write('\n')
    log.info('Stories saved to smart_stories.txt')
# Out:
# 2024-09-30 15:46:19,301 - INFO - Getting page https://www.thesmartfactory.io/smart-stories.html
# 2024-09-30 15:46:19,874 - INFO - Got page https://www.thesmartfactory.io/smart-stories.html with status code 200
# 2024-09-30 15:46:19,874 - INFO - Page content: <!DOCTYPE html>
# <html lang="en">
#
# <head>
# 	<meta charset="UTF-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1.0">
# 	<title>The Smart Factory - Smart Stories</title>
#
# 	<!-- Google Tag Manager -->
# 	<script>(function (w, d, s, l, i) {
# 			w[l] = w[l] || []; w[l].push({
# 				'gtm.start':
# 					new Date().getTime(), event: 'gtm.js'
# 			}); var f = d.getElementsByTagName(s)[0],
# 				j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# 					'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# 		})(window, document, 'script', 'dataLayer', 'GTM-KHMV3Z7J');</script>
# 	<!-- End Google Tag Manager -->
#
#
#
# 	<!-- OneTrust Cookies Consent Notice start for www.thesmartfactory.io -->
# 	<script type="text/javascript"
# 		src="https://cdn.cookielaw.org/consent/e92b575c-59a5-4919-a5c1-b83a667906ac/OtAutoBlock.js"></script>
# 	<script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charset="UTF-8"
# 		data-domain-script="e92b575c-59a5-4919-a5c1-b83a667906ac"></script>
# 	<script type="text/javascript">
# 		function OptanonWrapper() {
# 			otDeleteCookie();
# 			function otDeleteCookie() {
# 				var otDomainGrps = JSON.parse(JSON.stringify(Optanon.GetDomainData().Groups));
# 				var oneTrustAllGroups = otGetAllGroups();
# 				var otDeletedGrpIds = otGetInactiveId(oneTrustAllGroups, OnetrustActiveGroups);
# 				if (otDeletedGrpIds.length != 0 && otDomainGrps.length != 0) {
# 					for (var i = 0; i < otDomainGrps.length; i++) {
# 						if (otDomainGrps[i]['CustomGroupId'] != '' && otDeletedGrpIds.includes(otDomainGrps[i]['CustomGroupId'])) {
# 							for (var j = 0; j < otDomainGrps[i]['Cookies'].length; j++) {
# 								eraseCookie(otDomainGrps[i]['Cookies'][j]['Name'], otDomainGrps[i]['Cookies'][j]['Host']);
# 							}
# 						}
# 						if (otDomainGrps[i]['Hosts'].length != 0) {
# 							for (var j = 0; j < otDomainGrps[i]['Hosts'].length; j++) {
# 								if (otDeletedGrpIds.includes(otDomainGrps[i]['Hosts'][j]['HostId']) && otDomainGrps[i]['Hosts'][j]['Cookies'].length != 0) {
# 									for (var k = 0; k < otDomainGrps[i]['Hosts'][j]['Cookies'].length; k++) {
# 										eraseCookie(otDomainGrps[i]['Hosts'][j]['Cookies'][k]['Name'], otDomainGrps[i]['Hosts'][j]['Cookies'][k]['Host']);
# 									}
# 								}
# 							}
# 						}
# 					}
# 				}
# 			}
#
# 			function otGetInactiveId(customIniId, otActiveGrp) {
# 				customIniId = customIniId.split(",");
# 				customIniId = customIniId.filter(Boolean);
# 				otActiveGrp = otActiveGrp.split(",");
# 				otActiveGrp = otActiveGrp.filter(Boolean);
# 				var result = [];
# 				for (var i = 0; i < customIniId.length; i++) {
# 					if (otActiveGrp.indexOf(customIniId[i]) <= -1) {
# 						result.push(customIniId[i]);
# 					}
# 				}
# 				return result;
# 			}
#
# 			function eraseCookie(name, domain) {
# 				document.cookie = name + '=; Max-Age=-99999999; Path=/;Domain=' + window.location.hostname;
# 				document.cookie = name + '=; Max-Age=-99999999; Path=/;';
# 				if (domain) {
# 					document.cookie = name + '=; Max-Age=-99999999; Path=/;Domain=' + domain;
# 				}
# 				localStorage.removeItem(name);
# 				sessionStorage.removeItem(name);
# 			}
#
# 			function otGetAllGroups() {
# 				return Array.prototype.map.call(Optanon.GetDomainData().Groups, function (group) { return group.OptanonGroupId; }).join(",");
# 			}
# 		}
# 	</script>
# 	<!-- OneTrust Cookies Consent Notice end for www.thesmartfactory.io -->
# 	<!-- <script src="https://assets.adobedtm.com/571f1a0c43d6/d4821f404f8d/launch-3c4e646212bf-development.min.js" async></script> -->
# 	<script type="text/plain" src="https://assets.adobedtm.com/571f1a0c43d6/d4821f404f8d/launch-ddab7dcfd513.min.js"
# 		class="optanon-category-2" async></script>
# 	<script src="./assets/js/common.js" defer></script>
#   <link rel="stylesheet" href="/assets/styles-d3acd25d.css">
#   <link rel="stylesheet" href="/assets/hco_fonts-2ca14853.css">
# </head>
#
# <body>
# 	<!-- Google Tag Manager (noscript) -->
# 	<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-KHMV3Z7J" height="0" width="0"
# 			style="display:none;visibility:hidden"></iframe></noscript>
# 	<!-- End Google Tag Manager (noscript) -->
#
# 	<!-- MAIN NAV -->
# 	<nav class="bg-black sticky top-0 left-0 z-50" id="main-nav">
# 		<section class="relative lg:container mx-auto xxl:px-4 xl:px-4 bg-black flex item-center justify-between">
# 			<div class="sm:flex sm:items-center sm:justify-between sm:w-[90%] sm:pb-1 sm:pt-2 sm:mx-auto sm:px-0">
# 				<a class="block relative nav-area md:py-3" href="home.html">
# 							d="M11.6641 87.195H13.4369L15.8265 93.4153C16.3506 94.8339 16.6744 95.8608 16.8008 96.4899H16.881C16.9673 96.1507 17.1492 95.574 17.4236 94.7537C17.698 93.9334 18.5983 91.4138 20.1246 87.195H21.8974L17.2109 99.617C16.7453 100.844 16.2026 101.714 15.5829 102.229C14.9632 102.744 14.2016 103 13.2982 103C12.7925 103 12.2961 102.945 11.8059 102.83V101.507C12.1697 101.588 12.5798 101.628 13.0299 101.628C14.1646 101.628 14.9724 100.989 15.4596 99.7157L16.067 98.1614L11.6671 87.1919L11.6641 87.195Z"
# 							fill="white" />
# 					</svg>
# 				</a>
#
# 				<!-- Hamburger menu -->
# 				<button id="menu-btn" class="relative block xl:hidden focus:outline-none sm:h-[30px] sm:w-[47px]">
# 					<span class="hamburger-top"></span>
# 					<span class="hamburger-middle"></span>
# 					<span class="hamburger-bottom"></span>
# 				</button>
# 			</div>
#
#
# 			<ul class="hidden items-center space-x-1 font-nav xl:flex">
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[164px] h-[30px] text-center z-10"
# 						href="home.html">Make it possible</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[164px] h-[30px] text-center z-10"
# 						href="build-smart-manufacturing-value.html">Build smart value</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[164px] h-[30px] text-center z-10"
# 						href="our-smart-manufacturing-ecosystem.html">Our ecosystem</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[164px] h-[30px] text-center z-10"
# 						href="smart-factory-news.html">In the news</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[164px] h-[30px] text-center z-10"
# 						href="purpose.html">Our purpose</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[164px] h-[30px] text-center z-10"
# 						href="contact-us.html">Contact us</a>
# 				</li>
# 			</ul>
#
# 		</section>
#
# 		<!-- MOBILE MENU -->
# 		<div class="xl:hidden pt-10 pb-16 absolute bg-black w-full" id="mobile-menu">
# 			<ul class="id-engagement-first id-engagement-second items-center space-y-6 font-nav">
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[194px] h-[34px] text-center z-10 text-[0.875rem]"
# 						href="home.html">Make it possible</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[194px] h-[34px] text-center z-10 text-[0.875rem]"
# 						href="build-smart-manufacturing-value.html">Build smart value</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[194px] h-[34px] text-center z-10 text-[0.875rem]"
# 						href="our-smart-manufacturing-ecosystem.html">Our ecosystem</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[194px] h-[34px] text-center z-10 text-[0.875rem]"
# 						href="smart-factory-news.html">In the news</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[194px] h-[34px] text-center z-10 text-[0.875rem]"
# 						href="purpose.html">Our purpose</a>
# 				</li>
# 				<li class="id-engagement-first id-engagement-second primaryboxnavhover relative flex justify-center">
# 					<a class="flex justify-center border border-white items-center w-[194px] h-[34px] text-center z-10 text-[0.875rem]"
# 						href="contact-us.html">Contact us</a>
# 				</li>
# 			</ul>
# 		</div>
#
# 	</nav>
#
# 	<!-- HERO -->
# 	<header
# 		class="mainhero flex h-[322px] md:bg-[url('./smart-stories/desktop/smart-stories.webp')] bg-[url('./smart-stories/mobile/smart-stories-m.webp')] bg-cover relative">
# 		<div class="container absolute top-1/3 left-2/4 -translate-x-2/4 uppercase text-center w-full">
# 			<h2 class="font-title">Smart <span class="font-semibold">stories</span></h2>
# 		</div>
# 	</header>
#
# 	<!-- BREADCRUMBS -->
# 	<nav aria-label="Breadcrumb" class="container mx-auto uppercase text-[12px] tracking-[5.7px] mt-12">
# 		<ol class="flex">
# 			<li><span class="font-semibold">Smart stories</span></li>
# 		</ol>
# 	</nav>
#
# 	<!-- SMART STORIES -->
# 	<section class="container mx-auto mb-24">
#
# 		<article class="flex md:flex-row-reverse md:justify-start flex-col md:my-28 my-16">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-5/12">
# 				<img class="md:relative md:right-10" src="/assets/smarter-future-aerospace-337b457e.webp"
# 					alt="f35 jets flypast formation over the ocean low attitude">
# 			</div>
# 			<div class="md:w-7/12">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 sm:text-left">A smarter future for aerospace, driven by collaboration</h2>
# 				<h3 class="text-[24px] leading-[26px] mb-3">A conversation with Lindsey Berckman,<br>Deloitte Consulting
# 					principal</h3>
# 				<p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# 				<p class="md:mr-24 mt-5 leading-[20px]">To help crack the code to smart manufacturing excellence, we introduced
# 					an aerospace manufacturer to Deloitteâs Smart Manufacturing ecosystemâincluding other Deloitte clients and our
# 					alliance ecosystemâduring a visit to The Smart Factory by Deloitte @ Wichita. The goal was to show that
# 					anything is possible.<br> <br>
# 					<a href="smart-stories-a-smarter-future-for-aerospace.html" class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 			</div>
# 		</article>
#
# 		<article class="flex my-10 md:flex-row flex-col">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-2/6">
# 				<img src="/assets/power-up-34224a4e.webp" alt="Health care worker with a tablet and a stylus.">
# 			</div>
# 			<div class="md:w-4/6 md:ml-5">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 md:mr-36 sm:text-left">Power up: A smarter journey for a transformer
# 					manufacturer</h2>
# 				<h3 class="text-[24px] leading-[26px] mb-3">A conversation with Deloitteâs Rick Burke and Jon Tidd</h3>
# 				<p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# 				<p class="md:mr-36 mt-5 leading-[20px]">Deloitte Smart Manufacturing leaders Rick Burke and Jon Tidd are helping
# 					a transformer manufacturer take on a massive transformation of its own, fueled by a powerful cloud-enabled,
# 					integrated industrial development platform.<br><br>
# 					<a href="smart-stories-power-up-a-smarter-journey-for-a-transformer-manufacturer.html"
# 						class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 			</div>
# 		</article>
#
# 		<article class="flex md:flex-row-reverse md:justify-start flex-col md:my-28 my-16">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-5/12">
# 				<img class="md:relative md:right-10" src="/assets/future-smart-hospital-da907ea4.webp"
# 					alt="Health care worker with a tablet and a stylus.">
# 			</div>
# 			<div class="md:w-7/12">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 sm:text-left">Building a Smart <br> Hospital of the Future</h2>
# 				<h3 class="text-[24px] leading-[26px] mb-3">A conversation with Deloitte's Emily Duncan and Kurt Banas</h3>
# 				<p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# 				<p class="md:mr-36 mt-5 leading-[20px]">Emily Duncan, senior manager with Deloitte Consulting, and Kurt Banas,
# 					principal with Deloitte Consulting, are helping one of the largest health care systems in the world apply a
# 					âsmart factoryâ approach to their organization.<br> <br>
# 					<a href="smart-stories-smart-building-a-smart-hospital-of-the-future-today.html"
# 						class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 			</div>
# 		</article>
#
# 		<article class="flex my-10 md:flex-row flex-col">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-2/6">
# 				<img src="/assets/turbines-e6b2aa6b.webp" alt="Health care worker with a tablet and a stylus.">
# 			</div>
# 			<div class="md:w-4/6 md:ml-5">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 sm:text-left">Going Back to Basics <br> for Space Exploration</h2>
# 				<h3 class="text-[24px] md:mr-52 leading-[26px] mb-3">A conversation with Casey Dollinger, Deloitte Consulting
# 					manager</h3>
# 				<p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# 				<p class="md:mr-40 mt-5 leading-[20px]">How many people does it take to build a rocket engine? That's a question
# 					Casey Dollinger, a manager with Deloitte Consulting, is helping an aerospace manufacturer answer by harnessing
# 					the power of The Smart Factory @ Wichitaâs experiential center. And turns out, the answer isn't as simple as
# 					it seems. <br><br>
# 					<a href="smart-stories-smart-going-back-to-basics-for-space-exploration.html"
# 						class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 			</div>
# 		</article>
#
# 		<article class="flex md:flex-row-reverse md:justify-start flex-col md:my-28 my-16">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-5/12">
# 				<img class="md:relative md:right-10" src="/assets/smart-manufacturing-db2b11c2.webp"
# 					alt="Health care worker with a tablet and a stylus.">
# 			</div>
# 			<div class="md:w-7/12">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 sm:text-left">Smart Manufacturing: <br> The Complete Package</h2>
# 				<h3 class="text-[24px] md:mr-60 leading-[26px] mb-3">An overview with Jesse Storm</h3>
# 				<p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# 				<p class="md:mr-12 mt-5 leading-[20px]">Smart manufacturing has the power to transform. That's why so many
# 					manufacturers have taken the first step by investing in new equipment and technology. But, according to Jesse
# 					Storm, manager with Deloitte Consulting, technology is just part of the story. <br><br>
# 					<a href="smart-stories-the-complete-package.html" class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 			</div>
# 		</article>
#
# 		<article class="flex my-10 md:flex-row flex-col">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-2/6">
# 				<img src="/assets/cool-manufacturing-a1ab5d8b.webp"
# 					alt="Health care worker with a tablet and a stylus.">
# 			</div>
# 			<div class="md:w-4/6 md:ml-5">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 sm:text-left">What Makes Smart <br> Manufacturing so Cool?</h2>
# 				<h3 class="text-[24px] md:mr-60 leading-[26px] mb-3">A conversation with Michelle Davis, manager at Deloitte
# 					Consulting</h3>
# 				<p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# 				<p class="md:mr-40 mt-5 leading-[20px]">Michelle Davis wants you to believe&mdash;in the power of smart
# 					manufacturing, that you can build and scale a smart factory solution today, and that The Smart Factory @
# 					Wichita makes it happen.<br><br>
# 					<a href="smart-stories-what-makes-smart-manufacturing-cool.html" class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 				</p>
# 			</div>
# 		</article>
#
# 		<article class="flex md:flex-row-reverse flex-col justify-start md:my-28 my-16">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-5/12">
# 				<img class="md:relative md:right-10" src="/assets/smart-manufacturing-analytics-d72f106a.webp"
# 					alt="Health care worker with a tablet and a stylus.">
# 			</div>
# 			<div class="md:w-7/12">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 sm:text-left">Smart Manufacturing, <br> with an Analytics Twist</h2>
# 				<h3 class="text-[24px] md:mr-52 leading-[26px] mb-3">A conversation with Kimberly Hamrick, manager at Deloitte
# 					Consulting</h3>
# 				<p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# 				<p class="md:mr-12 mt-5 leading-[20px]">Kimberly Hamrick is in the business of digging deep to drive
# 					transformations for her clients. We sat down with the Deloitte Consulting manager to talk aerospace, agility,
# 					and the power of smart factory solutions. <br><br>
# 					<a href="smart-stories-smart-manufacturing-analytics-twist.html" class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 			</div>
# 		</article>
#
# 		<article class="flex my-10 md:flex-row flex-col">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-2/6">
# 				<img src="/assets/smart-manufacturing-baking-4e096a8d.webp"
# 					alt="Health care worker with a tablet and a stylus.">
# 			</div>
# 			<div class="md:w-4/6 md:ml-5">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 md:mr-36 sm:text-left">Smart Manufacturing: The Secret Ingredient to a
# 					Bakery's Success</h2>
# 				<h3 class="text-[24px] md:mr-60 leading-[26px] mb-3">Ideas from Brian Kiefer,<br> manager for Deloitte
# 					Consulting</h3>
# 				<p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# 				<p class="md:mr-40 mt-5 leading-[20px]">Smart manufacturing takes a lot of thought and planningâfor us and our
# 					clients.<br><br>
# 					<a href="smart-stories-secret-ingredient-to-a-bakerys-success.html" class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 				</p>
# 			</div>
# 		</article>
#
# 		<article class="flex md:flex-row-reverse flex-col justify-start md:my-28 my-16">
# 			<p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# 			<div class="md:w-5/12">
# 				<img class="md:relative md:right-10" src="/assets/digital-backbone-20f518bb.webp"
# 					alt="Health care worker with a tablet and a stylus.">
# 			</div>
# 			<div class="md:w-7/12">
# 				<p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# 				<h2 class="font-subtitle mt-6 mb-5 sm:text-left">Is Your Digital Backbone Strong Enough?</h2>
# 				<h3 class="text-[24px] md:mr-52 leading-[26px] mb-3">A conversation about MES<br> with Siemens' Raj Ragupathi
# 				</h3>
# 				<p class="text-[8px] font-bold uppercase">Siemens</p>
# 				<p class="md:mr-12 mt-5 leading-[20px]">Raj Ragupathi's love for smart manufacturing started before it was even
# 					a thing. As a high school intern with his family's automotive manufacturing business in India, he was
# 					fascinated with this intersection where ideas and design become reality. <br><br>
# 					<a href="smart-stories-is-your-digital-backbone-strong-enough.html" class="text-[13px] uppercase">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" width="16" height="17" viewBox="0 0 16 17" fill="none">
# 							<path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z"
# 								fill="#C96734"></path>
# 						</svg>
# 					</a>
# 				</p>
# 			</div>
# 		</article>
# 	</section>
#
# 	<!-- FOOTER -->
# 	<footer class="bg-secondaryDark">
#
# 		<section class="container mx-auto flex flex-col py-16">
# 			<section class="flex flex-row">
# 				<p class="flex text-[#ffffff80] uppercase md:w-1/4 w-screen text-[8px] tracking-[2.56px] relative top-1">
# 					<svg class="relative -top-2 -left-2" width="24" height="24" viewBox="0 0 24 24" fill="none">
# 						<path
# 							d="M12 21.896C10.2333 21.896 8.79167 21.6205 7.675 21.0694C6.55833 20.5183 6 19.8068 6 18.935C6 18.3592 6.24167 17.8575 6.725 17.4298C7.20833 17.0021 7.875 16.6649 8.725 16.4181L9.3 18.2934C9.01667 18.3757 8.75833 18.4785 8.525 18.6019C8.29167 18.7252 8.13333 18.8363 8.05 18.935C8.26667 19.1982 8.76667 19.4285 9.55 19.6259C10.3333 19.8233 11.15 19.922 12 19.922C12.85 19.922 13.6708 19.8233 14.4625 19.6259C15.2542 19.4285 15.7583 19.1982 15.975 18.935C15.8917 18.8363 15.7333 18.7252 15.5 18.6019C15.2667 18.4785 15.0083 18.3757 14.725 18.2934L15.3 16.4181C16.15 16.6649 16.8125 17.0021 17.2875 17.4298C17.7625 17.8575 18 18.3592 18 18.935C18 19.8068 17.4417 20.5183 16.325 21.0694C15.2083 21.6205 13.7667 21.896 12 21.896ZM12 18.935C11.8167 18.935 11.65 18.8815 11.5 18.7746C11.35 18.6677 11.2417 18.5237 11.175 18.3428C10.7917 17.1748 10.3083 16.196 9.725 15.4064C9.14167 14.6168 8.575 13.8601 8.025 13.1363C7.49167 12.4125 7.02917 11.664 6.6375 10.8908C6.24583 10.1177 6.05 9.16355 6.05 8.02849C6.05 6.38347 6.625 4.99342 7.775 3.85836C8.925 2.72329 10.3333 2.15576 12 2.15576C13.6667 2.15576 15.075 2.72329 16.225 3.85836C17.375 4.99342 17.95 6.38347 17.95 8.02849C17.95 9.16355 17.7583 10.1177 17.375 10.8908C16.9917 11.664 16.525 12.4125 15.975 13.1363C15.4417 13.8601 14.8792 14.6168 14.2875 15.4064C13.6958 16.196 13.2083 17.1748 12.825 18.3428C12.7583 18.5237 12.65 18.6677 12.5 18.7746C12.35 18.8815 12.1833 18.935 12 18.935ZM12 10.1259C12.5833 10.1259 13.0833 9.92026 13.5 9.50901C13.9167 9.09775 14.125 8.60425 14.125 8.02849C14.125 7.45273 13.9167 6.95923 13.5 6.54797C13.0833 6.13671 12.5833 5.93109 12 5.93109C11.4167 5.93109 10.9167 6.13671 10.5 6.54797C10.0833 6.95923 9.875 7.45273 9.875 8.02849C9.875 8.60425 10.0833 9.09775 10.5 9.50901C10.9167 9.92026 11.4167 10.1259 12 10.1259Z"
# 							fill="white" fill-opacity="0.5" />
# 					</svg>USA | Flagship location
# 				</p>
# 				<hr class="border-b-1 border-white md:w-full w-[11rem] relative top-2.5 -left-8">
# 			</section>
#
# 			<section class="flex py-6 justify-between md:flex-row flex-col">
# 				<section class="flex md:flex-row flex-col">
# 					<p class="text-white md:w-96 text-[11px] mr-12"><span class="uppercase font-bold">The Smart Factory by
# 							Deloitte @ Wichita</span> is one of Deloitte's several global immersive experiences designed in
# 						collaboration with ecosystem participants to accelerate digital transformation. It will demonstrate
# 						first-hand how manufacturers can evolve for the future and up-level their capabilities and processes through
# 						technological innovation.</p>
# 					<section class="md:mt-0 mt-10">
# 						<div class="flex flex-col mb-6 md:flex-row">
# 							<ul class="text-white uppercase leading-[20px] text-[13px] md:mr-8">
# 								<li><a class="tracking-[1px]" href="https://www2.deloitte.com/us/en/legal/privacy.html"
# 										target="_blank">Legal</a></li>
# 								<li><a class="tracking-[1px]" href="https://www2.deloitte.com/us/en/legal/terms-of-use.html"
# 										target="_blank">Terms of use</a></li>
# 							</ul>
# 							<ul class="text-white uppercase leading-[20px] text-[13px]">
# 								<li><a class="tracking-[1px]" href="https://cookienotice.deloitte.com/" target="_blank">Cookies</a></li>
# 								<li><a class="tracking-[1px] cursor-pointer optanon-toggle-display">Cookie settings</a></li>
# 							</ul>
# 						</div>
# 						<div class="flex space-x-2">
# 							<a href="https://www.instagram.com/smartfactoryx/" target="_blank">
# 								<svg width="18" height="19" viewBox="0 0 18 19" fill="none">
# 									<path
# 										d="M9.00066 0.610352C6.55638 0.610352 6.24963 0.621039 5.28962 0.664727C4.33148 0.708602 3.67748 0.860289 3.10522 1.08285C2.51328 1.31273 2.01115 1.62023 1.51089 2.12066C1.01026 2.62091 0.702757 3.12304 0.47213 3.71479C0.249003 4.28723 0.097126 4.94141 0.0540006 5.89916C0.0112501 6.85916 0 7.1661 0 9.61035C0 12.0546 0.0108753 12.3604 0.0543757 13.3204C0.0984387 14.2785 0.250128 14.9325 0.472505 15.5048C0.70257 16.0967 1.01007 16.5989 1.51052 17.0991C2.01058 17.5997 2.51271 17.908 3.10428 18.1379C3.67691 18.3604 4.33111 18.5121 5.28905 18.556C6.24906 18.5997 6.55563 18.6104 8.99972 18.6104C11.4442 18.6104 11.75 18.5997 12.71 18.556C13.6681 18.5121 14.3229 18.3604 14.8955 18.1379C15.4873 17.908 15.9887 17.5997 16.4887 17.0991C16.9894 16.5989 17.2969 16.0967 17.5275 15.505C17.7487 14.9325 17.9006 14.2784 17.9456 13.3206C17.9888 12.3606 18 12.0546 18 9.61035C18 7.1661 17.9888 6.85935 17.9456 5.89935C17.9006 4.94123 17.7487 4.28723 17.5275 3.71498C17.2969 3.12304 16.9894 2.62091 16.4887 2.12066C15.9881 1.62004 15.4875 1.31254 14.895 1.08285C14.3212 0.860289 13.6668 0.708602 12.7087 0.664727C11.7487 0.621039 11.4431 0.610352 8.99803 0.610352H9.00066ZM8.19327 2.23223C8.4329 2.23185 8.70028 2.23223 9.00066 2.23223C11.4037 2.23223 11.6885 2.24085 12.6374 2.28398C13.515 2.3241 13.9912 2.47073 14.3085 2.59391C14.7285 2.75704 15.0279 2.95204 15.3427 3.26704C15.6577 3.58204 15.8527 3.88204 16.0162 4.30204C16.1394 4.61891 16.2862 5.09516 16.3262 5.97266C16.3693 6.92141 16.3787 7.20641 16.3787 9.60829C16.3787 12.0102 16.3693 12.2952 16.3262 13.2439C16.286 14.1214 16.1394 14.5977 16.0162 14.9145C15.8531 15.3345 15.6577 15.6336 15.3427 15.9484C15.0277 16.2634 14.7287 16.4584 14.3085 16.6215C13.9916 16.7453 13.515 16.8915 12.6374 16.9317C11.6887 
# 							fill="white" fill-opacity="0.8"></path>
# 						<path
# 							d="M15.1336 4.28728C14.5382 3.70413 13.6922 3.40845 12.5957 3.40845C11.4458 3.40845 10.5629 3.7452 9.94276 4.41459C9.32265 5.08809 9.01465 6.04905 9.01465 7.3057C9.01465 8.56235 9.34729 9.46172 10.0167 10.1188C10.6861 10.7759 11.6265 11.1085 12.8339 11.1085C13.417 11.1085 13.9139 11.0674 14.3328 10.9894C14.7476 10.9114 15.1542 10.7718 15.5443 10.5664L15.1583 8.89089C14.8749 9.00588 14.6039 9.09622 14.3492 9.15372C13.9796 9.23996 13.5731 9.28102 13.1337 9.28102C12.6491 9.28102 12.2672 9.16193 11.9879 8.92785C11.7086 8.68966 11.5608 8.36523 11.5403 7.95046H16.0207V6.80879C16.0207 5.7082 15.7209 4.86633 15.1254 4.28317M11.5895 6.33652C11.6224 5.92996 11.7415 5.63017 11.9386 5.44126C12.1357 5.25235 12.3821 5.15379 12.6778 5.15379C12.9981 5.15379 13.2528 5.26057 13.4458 5.47412C13.6347 5.68766 13.7374 5.97513 13.7456 6.33242H11.5895V6.33652Z"
# 							fill="white" fill-opacity="0.8"></path>
# 					</svg>
# 				</p>
# 			</section>
#
# 		</section>
#
# 	</footer>
#
# </body>
#
# </html>
# 2024-09-30 15:46:19,875 - INFO - Parsing the page
# 2024-09-30 15:46:19,888 - INFO - Page Parsed: ['html', '\n', <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>The Smart Factory - Smart Stories</title>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
# 			w[l] = w[l] || []; w[l].push({
# 				'gtm.start':
# 					new Date().getTime(), event: 'gtm.js'
# 			}); var f = d.getElementsByTagName(s)[0],
# 				j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# 					'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# 		})(window, document, 'script', 'dataLayer', 'GTM-KHMV3Z7J');</script>
# <!-- End Google Tag Manager -->
# <!-- OneTrust Cookies Consent Notice start for www.thesmartfactory.io -->
# <script src="https://cdn.cookielaw.org/consent/e92b575c-59a5-4919-a5c1-b83a667906ac/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-domain-script="e92b575c-59a5-4919-a5c1-b83a667906ac" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		function OptanonWrapper() {
# 			otDeleteCookie();
# 			function otDeleteCookie() {
# 				var otDomainGrps = JSON.parse(JSON.stringify(Optanon.GetDomainData().Groups));
# 				var oneTrustAllGroups = otGetAllGroups();
# 				var otDeletedGrpIds = otGetInactiveId(oneTrustAllGroups, OnetrustActiveGroups);
# 				if (otDeletedGrpIds.length != 0 && otDomainGrps.length != 0) {
# 					for (var i = 0; i < otDomainGrps.length; i++) {
# 						if (otDomainGrps[i]['CustomGroupId'] != '' && otDeletedGrpIds.includes(otDomainGrps[i]['CustomGroupId'])) {
# 							for (var j = 0; j < otDomainGrps[i]['Cookies'].length; j++) {
# 								eraseCookie(otDomainGrps[i]['Cookies'][j]['Name'], otDomainGrps[i]['Cookies'][j]['Host']);
# 							}
# 						}
# 						if (otDomainGrps[i]['Hosts'].length != 0) {
# 							for (var j = 0; j < otDomainGrps[i]['Hosts'].length; j++) {
# 								if (otDeletedGrpIds.includes(otDomainGrps[i]['Hosts'][j]['HostId']) && otDomainGrps[i]['Hosts'][j]['Cookies'].length != 0) {
# 									for (var k = 0; k < otDomainGrps[i]['Hosts'][j]['Cookies'].length; k++) {
# 										eraseCookie(otDomainGrps[i]['Hosts'][j]['Cookies'][k]['Name'], otDomainGrps[i]['Hosts'][j]['Cookies'][k]['Host']);
# 									}
# 								}
# 							}
# 						}
# 					}
# 				}
# 			}
#
# 			function otGetInactiveId(customIniId, otActiveGrp) {
# 				customIniId = customIniId.split(",");
# ...
# <div class="md:w-5/12">
# <img alt="Health care worker with a tablet and a stylus." class="md:relative md:right-10" src="/assets/smart-manufacturing-analytics-d72f106a.webp"/>
# </div>
# <div class="md:w-7/12">
# <p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# <h2 class="font-subtitle mt-6 mb-5 sm:text-left">Smart Manufacturing, <br/> with an Analytics Twist</h2>
# <h3 class="text-[24px] md:mr-52 leading-[26px] mb-3">A conversation with Kimberly Hamrick, manager at Deloitte
# 					Consulting</h3>
# <p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# <p class="md:mr-12 mt-5 leading-[20px]">Kimberly Hamrick is in the business of digging deep to drive
# 					transformations for her clients. We sat down with the Deloitte Consulting manager to talk aerospace, agility,
# 					and the power of smart factory solutions. <br/><br/>
# <a class="text-[13px] uppercase" href="smart-stories-smart-manufacturing-analytics-twist.html">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" fill="none" height="17" viewbox="0 0 16 17" width="16">
# <path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z" fill="#C96734"></path>
# </svg>
# </a>
# </p>
# </div>
# </article>
# <article class="flex my-10 md:flex-row flex-col">
# <p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# <div class="md:w-2/6">
# <img alt="Health care worker with a tablet and a stylus." src="/assets/smart-manufacturing-baking-4e096a8d.webp"/>
# </div>
# <div class="md:w-4/6 md:ml-5">
# <p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# <h2 class="font-subtitle mt-6 mb-5 md:mr-36 sm:text-left">Smart Manufacturing: The Secret Ingredient to a
# 					Bakery's Success</h2>
# <h3 class="text-[24px] md:mr-60 leading-[26px] mb-3">Ideas from Brian Kiefer,<br/> manager for Deloitte
# 					Consulting</h3>
# <p class="text-[8px] font-bold uppercase">Deloitte Consulting</p>
# <p class="md:mr-40 mt-5 leading-[20px]">Smart manufacturing takes a lot of thought and planningâfor us and our
# 					clients.<br/><br/>
# <a class="text-[13px] uppercase" href="smart-stories-secret-ingredient-to-a-bakerys-success.html">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" fill="none" height="17" viewbox="0 0 16 17" width="16">
# <path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z" fill="#C96734"></path>
# </svg>
# </a>
# </p>
#
# </div>
# </article>
# <article class="flex md:flex-row-reverse flex-col justify-start md:my-28 my-16">
# <p class="uppercase bg-primary w-fit text-[10px] px-2 md:hidden mb-6">Smart story</p>
# <div class="md:w-5/12">
# <img alt="Health care worker with a tablet and a stylus." class="md:relative md:right-10" src="/assets/digital-backbone-20f518bb.webp"/>
# </div>
# <div class="md:w-7/12">
# <p class="uppercase bg-primary w-fit text-[10px] px-2 md:block sm:hidden">Smart story</p>
# <h2 class="font-subtitle mt-6 mb-5 sm:text-left">Is Your Digital Backbone Strong Enough?</h2>
# <h3 class="text-[24px] md:mr-52 leading-[26px] mb-3">A conversation about MES<br/> with Siemens' Raj Ragupathi
# 				</h3>
# <p class="text-[8px] font-bold uppercase">Siemens</p>
# <p class="md:mr-12 mt-5 leading-[20px]">Raj Ragupathi's love for smart manufacturing started before it was even
# 					a thing. As a high school intern with his family's automotive manufacturing business in India, he was
# 					fascinated with this intersection where ideas and design become reality. <br/><br/>
# <a class="text-[13px] uppercase" href="smart-stories-is-your-digital-backbone-strong-enough.html">Learn more
# 						<svg class="inline relative left-2 bottom-0.5" fill="none" height="17" viewbox="0 0 16 17" width="16">
# <path d="M8 16.5L6.575 15.1L12.175 9.5L0 9.5L0 7.5L12.175 7.5L6.575 1.9L8 0.5L16 8.5L8 16.5Z" fill="#C96734"></path>
# </svg>
# </a>
# </p>
# </div>
# </article>
# </section>
# <!-- FOOTER -->
# <footer class="bg-secondaryDark">
# <section class="container mx-auto flex flex-col py-16">
# <section class="flex flex-row">
# <p class="flex text-[#ffffff80] uppercase md:w-1/4 w-screen text-[8px] tracking-[2.56px] relative top-1">
# <svg class="relative -top-2 -left-2" fill="none" height="24" viewbox="0 0 24 24" width="24">
# <path d="M12 21.896C10.2333 21.896 8.79167 21.6205 7.675 21.0694C6.55833 20.5183 6 19.8068 6 18.935C6 18.3592 6.24167 17.8575 6.725 17.4298C7.20833 17.0021 7.875 16.6649 8.725 16.4181L9.3 18.2934C9.01667 18.3757 8.75833 18.4785 8.525 18.6019C8.29167 18.7252 8.13333 18.8363 8.05 18.935C8.26667 19.1982 8.76667 19.4285 9.55 19.6259C10.3333 19.8233 11.15 19.922 12 19.922C12.85 19.922 13.6708 19.8233 14.4625 19.6259C15.2542 19.4285 15.7583 19.1982 15.975 18.935C15.8917 18.8363 15.7333 18.7252 15.5 18.6019C15.2667 18.4785 15.0083 18.3757 14.725 18.2934L15.3 16.4181C16.15 16.6649 16.8125 17.0021 17.2875 17.4298C17.7625 17.8575 18 18.3592 18 18.935C18 19.8068 17.4417 20.5183 16.325 21.0694C15.2083 21.6205 13.7667 21.896 12 21.896ZM12 18.935C11.8167 18.935 11.65 18.8815 11.5 18.7746C11.35 18.6677 11.2417 18.5237 11.175 18.3428C10.7917 17.1748 10.3083 16.196 9.725 15.4064C9.14167 14.6168 8.575 13.8601 8.025 13.1363C7.49167 12.4125 7.02917 11.664 6.6375 10.8908C6.24583 10.1177 6.05 9.16355 6.05 8.02849C6.05 6.38347 6.625 4.99342 7.775 3.85836C8.925 2.72329 10.3333 2.15576 12 2.15576C13.6667 2.15576 15.075 2.72329 16.225 3.85836C17.375 4.99342 17.95 6.38347 17.95 8.02849C17.95 9.16355 17.7583 10.1177 17.375 10.8908C16.9917 11.664 16.525 12.4125 15.975 13.1363C15.4417 13.8601 14.8792 14.6168 14.2875 15.4064C13.6958 16.196 13.2083 17.1748 12.825 18.3428C12.7583 18.5237 12.65 18.6677 12.5 18.7746C12.35 18.8815 12.1833 18.935 12 18.935ZM12 10.1259C12.5833 10.1259 13.0833 9.92026 13.5 9.50901C13.9167 9.09775 14.125 8.60425 14.125 8.02849C14.125 7.45273 13.9167 6.95923 13.5 6.54797C13.0833 6.13671 12.5833 5.93109 12 5.93109C11.4167 5.93109 10.9167 6.13671 10.5 6.54797C10.0833 6.95923 9.875 7.45273 9.875 8.02849C9.875 8.60425 10.0833 9.09775 10.5 9.50901C10.9167 9.92026 11.4167 10.1259 12 10.1259Z" fill="white" fill-opacity="0.5"></path>
# </svg>USA | Flagship location
# 				</p>
# <hr class="border-b-1 border-white md:w-full w-[11rem] relative top-2.5 -left-8"/>
# </section>
# <section class="flex py-6 justify-between md:flex-row flex-col">
# <section class="flex md:flex-row flex-col">
# <p class="text-white md:w-96 text-[11px] mr-12"><span class="uppercase font-bold">The Smart Factory by
# 							Deloitte @ Wichita</span> is one of Deloitte's several global immersive experiences designed in
# 						collaboration with ecosystem participants to accelerate digital transformation. It will demonstrate
# 						first-hand how manufacturers can evolve for the future and up-level their capabilities and processes through
# 						technological innovation.</p>
# <section class="md:mt-0 mt-10">
# <div class="flex flex-col mb-6 md:flex-row">
# <ul class="text-white uppercase leading-[20px] text-[13px] md:mr-8">
# <li><a class="tracking-[1px]" href="https://www2.deloitte.com/us/en/legal/privacy.html" target="_blank">Legal</a></li>
# <li><a class="tracking-[1px]" href="https://www2.deloitte.com/us/en/legal/terms-of-use.html" target="_blank">Terms of use</a></li>
# </ul>
# <ul class="text-white uppercase leading-[20px] text-[13px]">
# <li><a class="tracking-[1px]" href="https://cookienotice.deloitte.com/" target="_blank">Cookies</a></li>
# <li><a class="tracking-[1px] cursor-pointer optanon-toggle-display">Cookie settings</a></li>
# </ul>
# </div>
# <div class="flex space-x-2">
# <a href="https://www.instagram.com/smartfactoryx/" target="_blank">
# <svg fill="none" height="19" viewbox="0 0 18 19" width="18">
# <path d="M9.00066 0.610352C6.55638 0.610352 6.24963 0.621039 5.28962 0.664727C4.33148 0.708602 3.67748 0.860289 3.10522 1.08285C2.51328 1.31273 2.01115 1.62023 1.51089 2.12066C1.01026 2.62091 0.702757 3.12304 0.47213 3.71479C0.249003 4.28723 0.097126 4.94141 0.0540006 5.89916C0.0112501 6.85916 0 7.1661 0 9.61035C0 12.0546 0.0108753 12.3604 0.0543757 13.3204C0.0984387 14.2785 0.250128 14.9325 0.472505 15.5048C0.70257 16.0967 1.01007 16.5989 1.51052 17.0991C2.01058 17.5997 2.51271 17.908 3.10428 18.1379C3.67691 18.3604 4.33111 18.5121 5.28905 18.556C6.24906 18.5997 6.55563 18.6104 8.99972 18.6104C11.4442 18.6104 11.75 18.5997 12.71 18.556C13.6681 18.5121 14.3229 18.3604 14.8955 18.1379C15.4873 17.908 15.9887 17.5997 16.4887 17.0991C16.9894 16.5989 17.2969 16.0967 17.5275 15.505C17.7487 14.9325 17.9006 14.2784 17.9456 13.3206C17.9888 12.3606 18 12.0546 18 9.61035C18 7.1661 17.9888 6.85935 17.9456 5.89935C